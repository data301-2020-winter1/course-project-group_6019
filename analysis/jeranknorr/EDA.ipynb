# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import Project_Functions_Copy1 as pf

data = pf.load_data()
pf.basics(data)
# Out:
#        Team            Full Name  Overall Rating Position  Age  Speed  \
# 0      Rams         Aaron Donald              99       RE   29     82
# 1  Patriots      Stephon Gilmore              99       CB   29     92
# 2  Panthers  Christian McCaffrey              99       HB   24     92
# 3    Chiefs      Patrick Mahomes              99       QB   24     81
# 4    Saints       Michael Thomas              99       WR   27     89
#
#    Acceleration  Awareness  Agility  Strength  ...  Jersey Number  \
# 0            90         99       86        99  ...             99
# 1            94         99       94        70  ...             24
# 2            93         97       97        72  ...             22
# 3            87         97       88        69  ...             15
# 4            92         99       92        77  ...             13
#
#        Total Salary     Signing Bonus          Archetype  \
# 0   $101,892,000.00    $40,000,000.00     DE_PowerRusher
# 1    $33,550,000.00    $31,450,000.00        CB_MantoMan
# 2    $45,840,000.00    $32,190,000.00   HB_ReceivingBack
# 3     $6,840,000.00    $34,420,000.00      QB_Improviser
# 4    $62,750,000.00    $35,130,000.00     WR_RouteRunner
#
#           Running Style  Years Pro  Height  Weight  Birthdate         College
# 0  Default Stride Loose          6      73     280  5/23/1991      Pittsburgh
# 1               Default          8      73     202  9/19/1990  South Carolina
# 2  Short Stride Default          3      71     205   6/7/1996        Stanford
# 3               Default          3      75     230  9/17/1995      Texas Tech
# 4               Default          4      75     212   3/3/1993      Ohio State
#
# [5 rows x 69 columns]
# (2293, 69)
# Index(['Team', 'Full Name', 'Overall Rating', 'Position', 'Age', 'Speed',
#        'Acceleration', 'Awareness', 'Agility', 'Strength', 'Throw Power',
#        'Throw On The Run', 'Throw Under Pressure', 'Throw Accuracy Short',
#        'Throw Accuracy Mid', 'Throw Accuracy Deep', 'Release',
#        'Ball Carrier Vision', 'Stamina', 'Carrying', 'Play Action', 'Pursuit',
#        'Play Recognition', 'Short Route Running', 'Medium Route Running',
#        'Deep Route Running', 'Catch In Traffic', 'Catching', 'Spin Move',
#        'Finesse Moves', 'Spectacular Catch', 'Jumping', 'Tackle',
#        'Zone Coverage', 'Man Coverage', 'Trucking', 'Juke Move', 'Break Sack',
#        'Toughness', 'Stiff Arm', 'Power Moves', 'Lead Blocking',
#        'Run Block Power', 'Run Blocking', 'Hit Power', 'Pass Block Finesse',
#        'Pass Block Power', 'Pass Blocking', 'Impact Blocking', 'Kick Return',
#        'Kick Accuracy', 'Break Tackle', 'Kick Power', 'Change Of Direction',
#        'Press', 'Block Shedding', 'Run Block Finesse', 'Injury',
#        'Player Handedness', 'Jersey Number', ' Total Salary ',
#        ' Signing Bonus ', 'Archetype', 'Running Style', 'Years Pro', 'Height',
#        'Weight', 'Birthdate', 'College'],
#       dtype='object')

# %%
data.describe(exclude=[np.number])
# Out:
#         Team    Full Name Position Player Handedness  Total Salary   \
# count   2293         2293     2293              2293           2293
# unique    32         2280       21                 2            822
# top     Jets  Chris Jones       WR             Right   $750,000.00
# freq      74            3      280              2243            136
#
#         Signing Bonus     Archetype           Running Style  Birthdate  \
# count             2293         2293                    2293       2293
# unique             639           46                      15       1630
# top              $-     CB_MantoMan  Default Stride Awkward  3/21/1995
# freq               694          152                     539          6
#
#         College
# Pass Blocking         2293.0   45.245094  16.783165    4.0   35.0   45.0
# Impact Blocking       2293.0   62.393807  19.781545   10.0   47.0   66.0
# Kick Return           2293.0   30.929350  26.411370    5.0   10.0   11.0
# Kick Accuracy         2293.0   19.812909  12.413905    6.0   13.0   17.0
# Break Tackle          2293.0   39.349760  25.708626    5.0   14.0   37.0
# Kick Power            2293.0   22.373310  14.610153    7.0   17.0   19.0
# Change Of Direction   2293.0   70.780201  13.743493   33.0   58.0   73.0
# Press                 2293.0   30.159180  24.117341    5.0   10.0   18.0
# Block Shedding        2293.0   45.672918  19.587129   10.0   28.0   45.0
# Run Block Finesse     2293.0   42.170955  17.754052   10.0   33.0   45.0
# Injury                2293.0   87.755778   3.713639   66.0   86.0   88.0
# Jersey Number         2293.0   50.421718  28.483310    1.0   26.0   50.0
# Years Pro             2293.0    3.356302   2.926373    0.0    1.0    3.0
# Height                2293.0   74.108591   2.659892   65.0   72.0   74.0
# Weight                2293.0  245.045792  46.715237  160.0  205.0  235.0
#
#                         75%    max
# Overall Rating         75.0   99.0
# Age                    27.0   43.0
# Speed                  88.0   99.0
# Acceleration           90.0   99.0
# Awareness              78.0   99.0
# Agility                86.0   98.0
# Strength               82.0   99.0
# Throw Power            34.0   99.0
# Throw On The Run       15.0   97.0
# Throw Under Pressure   17.0   98.0
# Throw Accuracy Short   20.0   99.0
# Throw Accuracy Mid     15.0   97.0
# Throw Accuracy Deep    12.0   96.0
# Release                50.0   99.0
# Ball Carrier Vision    73.0   98.0
# Stamina                88.0   99.0
# Carrying               69.0   98.0
# Play Action            14.0   99.0
# Pursuit                78.0   98.0
# Play Recognition       67.0   99.0
# Short Route Running    55.0   99.0
# Medium Route Running   49.0   98.0
# Deep Route Running     41.0   96.0
# Catch In Traffic       64.0   99.0
# Catching               71.0   99.0
# Spin Move              68.0   92.0
# Finesse Moves          54.0   97.0
# Spectacular Catch      66.0   99.0
# Jumping                86.0   99.0
# Tackle                 76.0   98.0
# Zone Coverage          59.0   98.0
# Man Coverage           54.0   99.0
# Trucking               51.0   91.0
# Juke Move              74.0   98.0
# Break Sack             22.0   98.0
# Toughness              88.0   99.0
# Stiff Arm              54.0   98.0
# Power Moves            55.0   99.0
# Lead Blocking          50.0   95.0
# Run Block Power        51.0   97.0
# Run Blocking           57.0   98.0
# Hit Power              77.0   98.0
# Pass Block Finesse     46.0   98.0
# Pass Block Power       50.0   98.0
# Pass Blocking          58.0   97.0
# Impact Blocking        79.0   96.0
# Kick Return            52.0   98.0
# Kick Accuracy          21.0   98.0
# Break Tackle           63.0   97.0
# Kick Power             22.0   99.0
# Change Of Direction    83.0   99.0
# Press                  48.0   99.0
# Block Shedding         63.0   97.0
# Run Block Finesse      50.0   98.0
# Injury                 90.0   99.0
# Jersey Number          75.0   99.0
# Years Pro               5.0   20.0
# Height                 76.0   81.0
# Weight                292.0  380.0

# %%
data.describe(include=[np.number])
# Out:
#        Overall Rating          Age        Speed  Acceleration    Awareness  \
# count     2293.000000  2293.000000  2293.000000   2293.000000  2293.000000
# mean        69.353685    25.744876    79.833842     85.297863    69.884431
# std         10.291734     3.078649    10.198032      5.687375    11.976678
# min         23.000000    20.000000    50.000000     63.000000    43.000000
# 25%         63.000000    24.000000    72.000000     81.000000    60.000000
# 50%         69.000000    25.000000    83.000000     87.000000    69.000000
# 75%         75.000000    27.000000    88.000000     90.000000    78.000000
# max         99.000000    43.000000    99.000000     99.000000    99.000000
#
#            Agility     Strength  Throw Power  Throw On The Run  \
# count  2293.000000  2293.000000  2293.000000       2293.000000
# mean     77.398168    72.404274    30.321413         14.686437
# std      10.914979    11.941032    15.607731         17.351282
# min      42.000000    25.000000     6.000000          5.000000
# 25%      69.000000    64.000000    22.000000          6.000000
# 50%      80.000000    73.000000    26.000000          6.000000
# 75%      86.000000    82.000000    34.000000         15.000000
# max      98.000000    99.000000    99.000000         97.000000
#
#        Throw Under Pressure  ...   Kick Power  Change Of Direction  \
# count           2293.000000  ...  2293.000000          2293.000000
# mean              18.084605  ...    22.373310            70.780201
# std               14.625869  ...    14.610153            13.743493
# min                0.000000  ...     7.000000            33.000000
# 25%               11.000000  ...    17.000000            58.000000
# 50%               14.000000  ...    19.000000            73.000000
# 75%               17.000000  ...    22.000000            83.000000
# max               98.000000  ...    99.000000            99.000000
#
#              Press  Block Shedding  Run Block Finesse       Injury  \
# count  2293.000000     2293.000000        2293.000000  2293.000000
# mean     30.159180       45.672918          42.170955    87.755778
# std      24.117341       19.587129          17.754052     3.713639
# min       5.000000       10.000000          10.000000    66.000000
# 25%      10.000000       28.000000          33.000000    86.000000
# 50%      18.000000       45.000000          45.000000    88.000000
# 75%      48.000000       63.000000          50.000000    90.000000
# max      99.000000       97.000000          98.000000    99.000000
#
#        Jersey Number    Years Pro       Height       Weight
# count    2293.000000  2293.000000  2293.000000  2293.000000
# mean       50.421718     3.356302    74.108591   245.045792
# std        28.483310     2.926373     2.659892    46.715237
# min         1.000000     0.000000    65.000000   160.000000
# 25%        26.000000     1.000000    72.000000   205.000000
# 50%        50.000000     3.000000    74.000000   235.000000
# 75%        75.000000     5.000000    76.000000   292.000000
# max        99.000000    20.000000    81.000000   380.000000
#
# [8 rows x 59 columns]

# %%
hist = data.hist(bins=10, figsize=(20,10))
hist
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x112925910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1129c5d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1129f7250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112a236a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112a4eaf0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112a7ce80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112a7cf70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112ab2490>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x112b0cca0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112b45130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112b725b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112b9da00>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112bcae50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112c022e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112c2d730>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112c59bb0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x112c870d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112cc04c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112ceb910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112d18d60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112d4f1f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112d7a6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112da9af0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11310efa0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x113144430>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113172880>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11319ecd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1131d6160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1132035b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11322ea60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11325beb0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11328cdc0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1132bf5b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1132e9d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11331d4f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113347c70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11337c490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1133a4c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1133d93d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113401b50>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x113438310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113463a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113498250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1134c19d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1134f6190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11351e910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113548130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11357a850>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1135a5fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1135dc790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113604f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11363a6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113662e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x113696610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1136c0d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1136f5550>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11371ecd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1137554f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112a41130>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112bae160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x112cca100>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11311f9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11326f2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1138499d0>]],
#       dtype=object)

# %%
import pandas_profiling
from pandas_profiling import ProfileReport
profile = ProfileReport(data, title='Pandas Profiling Report')
profile
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Summarize dataset', max=83.0, style=ProgressStyle(descrip…
